# %% [markdown]
# AMB2275_TANUJA SL

# %%
crop="rice"
soil_type="black soil"
print(crop)
print(soil_type)
# Out:
# rice
# black soil

# %%
crop="ground nut"
print(crop[0])
print(crop[-1])
print(crop[:5])
print(crop[5:])
# Out:
# g
# t
# groun
# d nut

# %%
print("rice".upper())
print("wheat".lower())
print("green gram".title())
print("cotton crop".capitalize())
# Out:
# RICE
# wheat
# Green Gram
# Cotton crop

# %%
raw_crop="rice"
print(raw_crop.strip())
print("***wheat".lstrip("*"))
print("maize###".rstrip("#"))
# Out:
# rice
# wheat
# maize

# %%
text="organic rice and rice cultivation "
print(text.find("rice"))
print(text.count("rice"))
print("rice" in text)
# Out:
# 8
# 2
# True

# %%
print("rice".isalpha())
print("2026".isdigit())
print("plot12".isalnum())
print(" ".isspace())
# Out:
# True
# True
# True
# True

# %%
crop_info="rice crop"
updated_crop_info=crop_info.replace("rice","wheat")
print(updated_crop_info)
# Out:
# wheat crop

# %%
#splitting an djoing of strings
record="rice,1200,blacksoil"
fields=record.split(",")
print(fields)
# Out:
# ['rice', '1200', 'blacksoil']

# %%
joined_record=",".join(fields)
print(joined_record)
# Out:
# rice,1200,blacksoil

# %%
#string formating
#it imporoves readability of output
yield_kg=1200
crop="rice"
print(f"crop:{crop},yield:{yield_kg}kg")
print("crop:crop{},yield:{}kg".format(crop,yield_kg))
# Out:
# crop:rice,yield:1200kg
# crop:croprice,yield:1200kg

# %%
#escape characters
print("line1\nline2")
print("sorted(wheat)")
# Out:
# line1
# line2
# sorted(wheat)
