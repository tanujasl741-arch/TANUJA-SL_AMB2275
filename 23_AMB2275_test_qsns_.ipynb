# %% [markdown]
# AMB2275_TANUJA SL

# %%
lst=[1,2,3]
for x in lst:
 lst.append(x)
 if len(lst)>4:
   break
print(lst)
# Out:
# [1, 2, 3, 1, 2]

# %%
squares=[]
for x in range(10):
  squares.append(x**2)
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
nums=[1,2,3,4]
squares=[]
for n in nums:
  squares.append(n**2)
print(squares)
# Out:
# [1, 4, 9, 16]

# %%
nums=[3,6,9,12]
total=0
for n in nums:
  total+=n
print(total)
# Out:
# 30

# %%
for i in range(1,6):
  if i%2==0:
    continue
  print(i)
# Out:
# 1
# 3
# 5
