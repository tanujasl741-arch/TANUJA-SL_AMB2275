# %% [markdown]
# AMB2275_TANUJA SL

# %%
1)  Create a List of soil moisture levels in percentage
                    soil_moisture = [45, 60, 30, 55, 40]
2)  display the values in the format 45 %
3)  if moisture < 50, display “Irrigation needed" else display as “Sufficient moisture"
4)  Display total number of fields tested (length)
5)  add new moisture value with 65 and check the count
6)  Remove 30 and check the count
7)  Sort the values
8)  Print max and min of the moisture value

# %%
# List of soil moisture levels in percentage
soil_moisture = [45, 60, 30, 55, 40]

# Display moisture levels
print("Soil moisture levels in different fields:")
for moisture in soil_moisture:
    print(moisture, "%")
# Out:
# Soil moisture levels in different fields:
# 45 %
# 60 %
# 30 %
# 55 %
# 40 %

# %%
# Check fields that need irrigation
print("Fields that need irrigation:")
for moisture in soil_moisture:
    if moisture < 50:
        print(moisture, "% - Irrigation needed")
    else:
        print(moisture, "% - Sufficient moisture")

# Total number of fields
print("Total fields checked:", len(soil_moisture))
# Out:
# Fields that need irrigation:
# 45 % - Irrigation needed
# 60 % - Sufficient moisture
# 30 % - Irrigation needed
# 55 % - Sufficient moisture
# 40 % - Irrigation needed
# Total fields checked: 5

# %%
# Add a new field moisture value
soil_moisture.append(65)
print("After adding new field moisture:")
print(soil_moisture)
# Total number of fields
print("Total fields checked:", len(soil_moisture))

# Remove a moisture value
soil_moisture.remove(30)
print("After removing 30% moisture value:")
print(soil_moisture)
# Total number of fields
print("Total fields checked:", len(soil_moisture))
# Out:
# After adding new field moisture:
# [45, 60, 30, 55, 40, 65]
# Total fields checked: 6
# After removing 30% moisture value:
# [45, 60, 55, 40, 65]
# Total fields checked: 5

# %%
# Sort moisture levels
soil_moisture.sort()
print("Moisture levels after sorting:")
print(soil_moisture)

# Find minimum and maximum moisture
print("Minimum moisture:", min(soil_moisture), "%")
print("Maximum moisture:", max(soil_moisture), "%")
# Out:
# Moisture levels after sorting:
# [40, 45, 55, 60, 65]
# Minimum moisture: 40 %
# Maximum moisture: 65 %
